# %% [markdown]
# #### General data visualization

# %%
# library imports
import pandas as pd

# %%
# initializing the data file
df = pd.read_csv('/home/sr42/catkin_ws/src/vayubhoomi-uav-ugv/src/vision/src/positions.csv')
df.head()
# Out:
#   frameNumber                   x                   y
# 0           1  0.0564144544633608  0.0580604664669539
# 1           4  0.0564156310639832  0.0580617172266324
# 2           6   0.056416966703973  0.0580641109167233
# 3           7  0.0564174468324483  0.0580647760396672
# 4           8  0.0565100484555477  0.0580714243350018

# %%
# visualizing the data
df.plot.scatter(title='Pose', x='x', y='y', s=1, colormap='viridis')
